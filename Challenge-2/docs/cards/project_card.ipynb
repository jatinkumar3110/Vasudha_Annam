# %%
"""Objective:
Build a deep learning model to classify soil images from non-soil images using anomaly detection techniques.

Dataset:

Images from Kaggle Soil Classification Challenge 2

Training and test images hosted on Google Drive

Labeled CSV files with soil/non-soil classes

Model:

Autoencoder leveraging pretrained ResNet18 encoder

Decoder reconstructs 224x224 RGB images

Trained on soil images only to learn normal patterns

Tech Stack:

Python, PyTorch, torchvision

Google Colab & Google Drive for data handling

NumPy, Pandas, Matplotlib, Seaborn for data manipulation and visualization

Training Details:

Batch size: 32

Loss: Mean Squared Error (MSE)

Optimizer: Adam (lr=0.001)

Early stopping based on validation loss

Performance:

Validation loss improved to 0.92 (MSE)

F1-score: ~0.92 on validation

ROC-AUC: ~0.95

Challenges:

Class imbalance handled by training only on soil images for anomaly detection

Ensuring output dimensions matched input during decoding

Future Work:

Experiment with more advanced architectures (e.g., variational autoencoders)

Fine-tune thresholds for optimal classification

Extend to multiclass soil type classification"""
